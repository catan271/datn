# %%
# %load_ext autoreload
# %autoreload 2

from dotenv import load_dotenv
import pandas as pd
import numpy as np
import os
import sys
import datetime

root_path = os.path.abspath(os.path.join('..'))
if root_path not in sys.path:
    sys.path.append(root_path)
    

load_dotenv()
# Out:
# True

# %%
from utils.utils import date_range, preprocess_c

df_test = pd.concat([
    pd.read_csv(f'../.data/test.csv'),
])

X1_test, X2_test, y_test = preprocess_c(df_test)

X1_test.shape, X2_test.shape, y_test.shape
# Out:
# ((125, 1, 3), (125, 14, 3), (125, 3))

# %%
from keras.models import Model, load_model

from utils.utils import plot_accuracy, data_descale

# %%
# test predict view
model_view: Model = load_model('../model/c-view.keras')
p_view = model_view.predict([X1_test, X2_test])
p_view = data_descale(p_view[:, 0], 'view')
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
df = pd.DataFrame({
    'view': p_view
})
df.plot()
# Out:
# <Axes: >

# %%
X1_test
# Out:
# array([[[1.        , 0.87417219, 0.03325909]],
#
#        [[0.99925871, 0.87417219, 0.03325909]],
#
#        [[0.99851742, 0.87417219, 0.03325909]],
#
#        [[0.99777613, 0.87417219, 0.03325909]],
#
#        [[0.99703484, 0.87417219, 0.03325909]],
#
#        [[0.99629355, 0.87417219, 0.03325909]],
#
#        [[0.99555226, 0.87417219, 0.03325909]],
#
#        [[0.99481097, 0.87417219, 0.03325909]],
#
#        [[0.99406968, 0.87417219, 0.03325909]],
#
#        [[0.99332839, 0.87417219, 0.03325909]],
#
#        [[0.9925871 , 0.87417219, 0.03325909]],
#
#        [[0.99184581, 0.87417219, 0.03325909]],
#
#        [[0.99110452, 0.87417219, 0.03325909]],
#
#        [[0.99036323, 0.87417219, 0.03325909]],
#
#        [[0.98962194, 0.87417219, 0.03325909]],
#
#        [[0.98888065, 0.87417219, 0.03325909]],
#
#        [[0.98813936, 0.87417219, 0.03325909]],
#
#        [[0.98739807, 0.87417219, 0.03325909]],
#
#        [[0.98665678, 0.87417219, 0.03325909]],
#
#        [[0.98591549, 0.87417219, 0.03325909]],
#
#        [[0.9851742 , 0.87417219, 0.03325909]],
#
#        [[0.98443291, 0.87417219, 0.03325909]],
#
#        [[0.98369162, 0.87417219, 0.03325909]],
#
#        [[0.98295033, 0.87417219, 0.03325909]],
#
#        [[0.98220904, 0.87417219, 0.03325909]],
#
#        [[0.98146775, 0.87417219, 0.03325909]],
#
#        [[0.98072646, 0.87417219, 0.03325909]],
#
#        [[0.97998517, 0.87417219, 0.03325909]],
#
#        [[0.97924388, 0.87417219, 0.03325909]],
#
#        [[0.97850259, 0.87417219, 0.03325909]],
#
#        [[0.9777613 , 0.87417219, 0.03325909]],
#
#        [[0.97702001, 0.87417219, 0.03325909]],
#
#        [[0.97627872, 0.87417219, 0.03325909]],
#
#        [[0.97553744, 0.87417219, 0.03325909]],
#
#        [[0.97479615, 0.87417219, 0.03325909]],
#
#        [[0.97405486, 0.87417219, 0.03325909]],
#
#        [[0.97331357, 0.87417219, 0.03325909]],
#
#        [[0.97257228, 0.87417219, 0.03325909]],
#
#        [[0.97183099, 0.87417219, 0.03325909]],
#
#        [[0.9710897 , 0.87417219, 0.03325909]],
#
#        [[0.97034841, 0.87417219, 0.03325909]],
#
#        [[0.96960712, 0.87417219, 0.03325909]],
#
#        [[0.96886583, 0.87417219, 0.03325909]],
#
#        [[0.96812454, 0.87417219, 0.03325909]],
#
#        [[0.96738325, 0.87417219, 0.03325909]],
#
#        [[0.96664196, 0.87417219, 0.03325909]],
#
#        [[0.96590067, 0.87417219, 0.03325909]],
#
#        [[0.96515938, 0.87417219, 0.03325909]],
#
#        [[0.96441809, 0.87417219, 0.03325909]],
#
#        [[0.9636768 , 0.87417219, 0.03325909]],
#
#        [[0.96293551, 0.87417219, 0.03325909]],
#
#        [[0.96219422, 0.87417219, 0.03325909]],
#
#        [[0.96145293, 0.87417219, 0.03325909]],
#
#        [[0.96071164, 0.87417219, 0.03325909]],
#
#        [[0.95997035, 0.87417219, 0.03325909]],
#
#        [[0.95922906, 0.87417219, 0.03325909]],
#
#        [[0.95848777, 0.87417219, 0.03325909]],
#
#        [[0.95774648, 0.87417219, 0.03325909]],
#
#        [[0.95700519, 0.87417219, 0.03325909]],
#
#        [[0.9562639 , 0.87417219, 0.03325909]],
#
#        [[0.95552261, 0.87417219, 0.03325909]],
#
#        [[0.95478132, 0.87417219, 0.03325909]],
#
#        [[0.95404003, 0.87417219, 0.03325909]],
#
#        [[0.95329874, 0.87417219, 0.03325909]],
#
#        [[0.95255745, 0.87417219, 0.03325909]],
#
#        [[0.95181616, 0.87417219, 0.03325909]],
#
#        [[0.95107487, 0.87417219, 0.03325909]],
#
#        [[0.95033358, 0.87417219, 0.03325909]],
#
#        [[0.94959229, 0.87417219, 0.03325909]],
#
#        [[0.948851  , 0.87417219, 0.03325909]],
#
#        [[0.94810971, 0.87417219, 0.03325909]],
#
#        [[0.94736842, 0.87417219, 0.03325909]],
#
#        [[0.94662713, 0.87417219, 0.03325909]],
#
#        [[0.94588584, 0.87417219, 0.03325909]],
#
#        [[0.94514455, 0.87417219, 0.03325909]],
#
#        [[0.94440326, 0.87417219, 0.03325909]],
#
#        [[0.94366197, 0.87417219, 0.03325909]],
#
#        [[0.94292068, 0.87417219, 0.03325909]],
#
#        [[0.94217939, 0.87417219, 0.03325909]],
#
#        [[0.9414381 , 0.87417219, 0.03325909]],
#
#        [[0.94069681, 0.87417219, 0.03325909]],
#
#        [[0.93995552, 0.87417219, 0.03325909]],
#
#        [[0.93921423, 0.87417219, 0.03325909]],
#
#        [[0.93847294, 0.87417219, 0.03325909]],
#
#        [[0.93773165, 0.87417219, 0.03325909]],
#
#        [[0.93699036, 0.87417219, 0.03325909]],
#
#        [[0.93624907, 0.87417219, 0.03325909]],
#
#        [[0.93550778, 0.87417219, 0.03325909]],
#
#        [[0.93476649, 0.87417219, 0.03325909]],
#
#        [[0.9340252 , 0.87417219, 0.03325909]],
#
#        [[0.93328391, 0.87417219, 0.03325909]],
#
#        [[0.93254262, 0.87417219, 0.03325909]],
#
#        [[0.93180133, 0.87417219, 0.03325909]],
#
#        [[0.93106004, 0.87417219, 0.03325909]],
#
#        [[0.93031875, 0.87417219, 0.03325909]],
#
#        [[0.92957746, 0.87417219, 0.03325909]],
#
#        [[0.92883617, 0.87417219, 0.03325909]],
#
#        [[0.92809489, 0.87417219, 0.03325909]],
#
#        [[0.9273536 , 0.87417219, 0.03325909]],
#
#        [[0.92661231, 0.87417219, 0.03325909]],
#
#        [[0.92587102, 0.87417219, 0.03325909]],
#
#        [[0.92512973, 0.87417219, 0.03325909]],
#
#        [[0.92438844, 0.87417219, 0.03325909]],
#
#        [[0.92364715, 0.87417219, 0.03325909]],
#
#        [[0.92290586, 0.87417219, 0.03325909]],
#
#        [[0.92216457, 0.87417219, 0.03325909]],
#
#        [[0.92142328, 0.87417219, 0.03325909]],
#
#        [[0.92068199, 0.87417219, 0.03325909]],
#
#        [[0.9199407 , 0.87417219, 0.03325909]],
#
#        [[0.91919941, 0.87417219, 0.03325909]],
#
#        [[0.91845812, 0.87417219, 0.03325909]],
#
#        [[0.91771683, 0.87417219, 0.03325909]],
#
#        [[0.91697554, 0.87417219, 0.03325909]],
#
#        [[0.91623425, 0.87417219, 0.03325909]],
#
#        [[0.91549296, 0.87417219, 0.03325909]],
#
#        [[0.91475167, 0.87417219, 0.03325909]],
#
#        [[0.91401038, 0.87417219, 0.03325909]],
#
#        [[0.91326909, 0.87417219, 0.03325909]],
#
#        [[0.9125278 , 0.87417219, 0.03325909]],
#
#        [[0.91178651, 0.87417219, 0.03325909]],
#
#        [[0.91104522, 0.87417219, 0.03325909]],
#
#        [[0.91030393, 0.87417219, 0.03325909]],
#
#        [[0.90956264, 0.87417219, 0.03325909]],
#
#        [[0.90882135, 0.87417219, 0.03325909]],
#
#        [[0.90808006, 0.87417219, 0.03325909]]])
