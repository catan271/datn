# %%
# %load_ext autoreload
# %autoreload 2

from dotenv import load_dotenv
import pandas as pd
import numpy as np
import os
import sys
import datetime

root_path = os.path.abspath(os.path.join('..'))
if root_path not in sys.path:
    sys.path.append(root_path)
    

load_dotenv()
# Out:
# True

# %%
from utils.utils import date_range, preprocess_c

df_test = pd.concat([
    pd.read_csv(f'../.data/test.csv'),
])

X1_test, X2_test, y_test = preprocess_c(df_test)

X1_test.shape, X2_test.shape, y_test.shape
# Out:
# ((1242, 1, 3), (1242, 14, 3), (1242, 3))

# %%
from keras.models import Model, load_model

from utils.utils import plot_accuracy, data_descale

# %%
# test predict view
model_view: Model = load_model('../model/c-view.keras')
p_view = model_view.predict([X1_test, X2_test])
p_view = data_descale(p_view[:, 0], 'view')
# Out:
# 39/39 [==============================] - 0s 2ms/step

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
df = pd.DataFrame({
    'view': p_view
})
df.plot()
# Out:
# <Axes: >

# %%
X1_test
# Out:
# array([[[1.        , 0.35761589, 0.01467672]],
#
#        [[0.99925871, 0.35761589, 0.01467672]],
#
#        [[0.99851742, 0.35761589, 0.01467672]],
#
#        ...,
#
#        [[0.08154188, 0.35761589, 0.01467672]],
#
#        [[0.08080059, 0.35761589, 0.01467672]],
#
#        [[0.0800593 , 0.35761589, 0.01467672]]])
