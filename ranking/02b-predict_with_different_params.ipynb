# %%
# %load_ext autoreload
# %autoreload 2

from dotenv import load_dotenv
import pandas as pd
import numpy as np
import os
import sys
import datetime

root_path = os.path.abspath(os.path.join('..'))
if root_path not in sys.path:
    sys.path.append(root_path)
    

load_dotenv()
# Out:
# True

# %%
from utils.utils import date_range, preprocess_b

df_test = pd.concat([
    pd.read_csv(f'../.data/test.csv'),
])

X_test, y_test = preprocess_b(df_test)

X_test.shape, y_test.shape
# Out:
# ((125, 24), (125, 3))

# %%
from keras.models import Model, load_model

from utils.utils import plot_accuracy, data_descale

# %%
# test predict purchase
import matplotlib.pyplot as plt

model_purchase: Model = load_model('../model/b-purchase.keras')
p_purchase = model_purchase.predict(X_test)
p_purchase = data_descale(p_purchase[:, 0], 'purchase')

plt.figure(figsize=(10, 6))
df = pd.DataFrame({
    'purchase': p_purchase
})
df.plot()
# Out:
# 4/4 [==============================] - 0s 1ms/step
# <Axes: >

# %%
df_test
# Out:
#      view  cart  purchase  rank_in_category  days_on_shelf  price  view_prev1  \
# 0     112    53        15                 1            132  10.95         112
# 1     112    53        15                 1            131  10.95         112
# 2     112    53        15                 1            130  10.95         112
# 3     112    53        15                 1            129  10.95         112
# 4     112    53        15                 1            128  10.95         112
# ..    ...   ...       ...               ...            ...    ...         ...
# 120   112    53        15                 1             12  10.95         112
# 121   112    53        15                 1             11  10.95         112
# 122   112    53        15                 1             10  10.95         112
# 123   112    53        15                 1              9  10.95         112
# 124   112    53        15                 1              8  10.95         112
#
#      cart_prev1  purchase_prev1  view_prev2  ...  purchase_prev11  \
# 0            58              18         116  ...               17
# 1            58              18         116  ...               17
# 2            58              18         116  ...               17
# 3            58              18         116  ...               17
# 4            58              18         116  ...               17
# ..          ...             ...         ...  ...              ...
# 120          58              18         116  ...               17
# 121          58              18         116  ...               17
# 122          58              18         116  ...               17
# 123          58              18         116  ...               17
# 124          58              18         116  ...               17
#
#      view_prev12  cart_prev12  purchase_prev12  view_prev13  cart_prev13  \
# 0            170           69               21          167          129
# 1            170           69               21          167          129
# 2            170           69               21          167          129
# 3            170           69               21          167          129
# 4            170           69               21          167          129
# ..           ...          ...              ...          ...          ...
# 120          170           69               21          167          129
# 121          170           69               21          167          129
# 122          170           69               21          167          129
# 123          170           69               21          167          129
# 124          170           69               21          167          129
#
#      purchase_prev13  view_prev14  cart_prev14  purchase_prev14
# 0                 56          176          123               47
# 1                 56          176          123               47
# 2                 56          176          123               47
# 3                 56          176          123               47
# 4                 56          176          123               47
# ..               ...          ...          ...              ...
# 120               56          176          123               47
# 121               56          176          123               47
# 122               56          176          123               47
# 123               56          176          123               47
# 124               56          176          123               47
#
# [125 rows x 48 columns]

# %%
p_purchase
# Out:
# array([16.405317, 16.398151, 16.39098 , 16.383816, 16.376648, 16.369293,
#        16.360033, 16.350769, 16.341507, 16.342445, 16.344667, 16.346945,
#        16.350897, 16.354847, 16.358797, 16.362747, 16.3667  , 16.37065 ,
#        16.3746  , 16.37855 , 16.382502, 16.386452, 16.386347, 16.385405,
#        16.384468, 16.383524, 16.382584, 16.381641, 16.380701, 16.37976 ,
#        16.37882 , 16.37788 , 16.376936, 16.375998, 16.375057, 16.37488 ,
#        16.375929, 16.376976, 16.38051 , 16.384424, 16.388342, 16.392262,
#        16.393059, 16.39319 , 16.393324, 16.394371, 16.395897, 16.397629,
#        16.400589, 16.40355 , 16.406511, 16.411173, 16.415989, 16.42126 ,
#        16.426884, 16.432508, 16.438133, 16.443754, 16.449379, 16.455   ,
#        16.460625, 16.466248, 16.471869, 16.477493, 16.483116, 16.488743,
#        16.494364, 16.499985, 16.505611, 16.511234, 16.516857, 16.52248 ,
#        16.528107, 16.53474 , 16.552164, 16.56959 , 16.587013, 16.60444 ,
#        16.621864, 16.63929 , 16.656715, 16.674143, 16.691565, 16.708992,
#        16.718596, 16.719452, 16.72031 , 16.721169, 16.722029, 16.722815,
#        16.723352, 16.72389 , 16.724432, 16.724972, 16.72551 , 16.72605 ,
#        16.726421, 16.72651 , 16.726595, 16.726686, 16.72677 , 16.72686 ,
#        16.726946, 16.727037, 16.727121, 16.720068, 16.706167, 16.6901  ,
#        16.674992, 16.661057, 16.647121, 16.633186, 16.61925 , 16.605314,
#        16.59138 , 16.577444, 16.563507, 16.549572, 16.535635, 16.52127 ,
#        16.506718, 16.492167, 16.477613, 16.46306 , 16.44851 ],
#       dtype=float32)
